# %% [markdown]
# <a href="https://colab.research.google.com/github/Poojithadevi14/FMML_PROJECTS_AND_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 16:18:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   185MB/s    in 0.4s
#
# 2024-04-02 16:18:35 (185 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5501    1205.2171v2  We study the problem of structured output lear...  stat
# 21637   1209.0367v2  Given two graphs, the graph matching problem i...  stat
# 28080  1705.05902v1  We continue the development of a linear algebr...    cs
# 8570   1705.07404v1  We propose a novel neural network structure ca...    cs
# 12410  1801.05504v1  Neural network based architectures used for so...    cs
# ...             ...                                                ...   ...
# 5287    1209.5467v4  Brain signal variability in the measurements o...  stat
# 5274    1209.1077v1  We study the problem of estimating, in the sen...    cs
# 33108  1802.05054v1  In continuous action domains, standard deep re...    cs
# 2167   1611.08366v1  Multivariate Pattern (MVP) classification can ...  stat
# 2124   1511.06890v1  This paper presents a novel nonmyopic adaptive...  stat
#
#                                                    title  year  \
# 5501   A Generalized Kernel Approach to Structured Ou...  2012
# 21637                              Seeded Graph Matching  2012
# 28080  What's In A Patch, II: Visualizing generic sur...  2017
# 8570      CrossNets : A New Approach to Complex Learning  2017
# 12410  Automatic Classification of Music Genre using ...  2018
# ...                                                  ...   ...
# 5287   Minimizing inter-subject variability in fNIRS ...  2012
# 5274   Learning Probability Measures with respect to ...  2012
# 33108  GEP-PG: Decoupling Exploration and Exploitatio...  2018
# 2167   Local Discriminant Hyperalignment for multi-su...  2016
# 2124   Gaussian Process Planning with Lipschitz Conti...  2015
#
#                                                 keywords
# 5501   [structured, regression, perspective, formulat...
# 21637  [adjacency, disagreements, alignment, completi...
# 28080  [development, algebraic, framework, exploiting...
# 8570   [structure, crossnets, considers, architecture...
# 12410  [architectures, recognition, application, reco...
# ...                                                  ...
# 5287   [variability, measurements, different, differe...
# 5274   [estimating, transport, supported, establishin...
# 33108  [continuous, reinforcement, algorithms, ineffi...
# 2167   [multivariate, classification, different, cogn...
# 2124   [nonmyopic, framework, lipschitz, continuous, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5501     [structured, regression, perspective, formulat...
# 21637    [adjacency, disagreements, alignment, completi...
# 28080    [development, algebraic, framework, exploiting...
# 8570     [structure, crossnets, considers, architecture...
# 12410    [architectures, recognition, application, reco...
#                                ...
# 31213    [geotagged, geographic, knowledge, discovery, ...
# 4744     [withdrawn, withdrawn, unfortunately, precondi...
# 22421    [ensembles, prediction, performance, interpret...
# 25291    [supervised, initialization, alignment, estima...
# 26878    [convolution, unprecedentedly, effective, repr...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8875 words.
# Out of those 4525 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4167f715-f6ff-4e95-a34a-98517fd5ef88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4167f715-f6ff-4e95-a34a-98517fd5ef88")) {                    Plotly.newPlot(                        "4167f715-f6ff-4e95-a34a-98517fd5ef88",                        [{"x":["correlation","formulations","generalized","dependency","estimation","structure","conditional","introduce","covariance","regression","framework","performance","structured","interactions","variables","perspective","formulation","reference","demonstrate","differently","simulation","naturally","disagreements","experiments","knowledge","effectiveness","partially","completing","alignment","individual","effective","nomination","applicability","extremely","adjacency","approximate","algorithm","algebraic","development","constraint","encapsulate","restricts","visualizing","arbitrary","parameters","polynomial","exploiting","consistent","differentiated","derivatives","solutions","expansions","ambiguity","connections","information","increases","performances","backpropagation","convergence","architectures","considers","generalizations","benchmark","outperformed","classification","operation","convolutional","sparseness","frequency","recognition","collection","additionally","handcrafting","representation","representations","application","extension","competitive","concurrently","susceptibility","analogous","exploration","multidimensional","automatic","decreases","systematic","combinations","distributed","experiment","quantization","sufficient","quantized","characterized","iteration","coordinate","conditions","assumption","precision","randomized","practical","complexity","literature","theoretical","deviation","denoising","efficiency","population","computation","justified","independent","additional","filtering","intensity","observation","injection","treatment","traditional","experimental","technique","reduction","restoration","statistical","neighbourhood","ultrasound","lipschitz","especially","exponential","logarithm","concurrent","randomised","continuous","parallelisation","numerical","approaches","expectation","maximizing","discrimination","potentially","discriminant","decomposed","comparisons","likelihood","significantly","alternative","simulated","dedicated","outperforms","integrates","heterogeneity","homogeneous","particularly","including","functional","approximation","performed","maximization","explicitly","presenting","observations","hyperparameter","probabilistic","predictions","different","hyperparameters","specified","integrating","dependencies","explanations","integration","submodular","phenomenon","computational","recommendation","advertisements","properties","increased","combinatorial","straightforward","computationally","intractable","encounters","challenge","objective","particular","efficient","formulate","optimization","recommend","terminate","formulated","specifically","assumptions","adversary","arbitrarily","delivered","resorting","celebrated","adversarial","distributional","encompasses"],"y":[69,16,65,49,209,329,91,321,13,114,545,893,100,76,136,64,71,59,609,11,80,54,1,583,379,200,51,3,48,135,254,0,32,36,4,124,804,23,125,83,4,4,13,91,260,66,83,79,4,16,158,3,17,40,702,57,49,20,117,114,34,15,209,15,509,44,372,5,46,394,80,67,2,364,241,235,81,122,4,2,15,56,16,189,28,40,48,102,69,20,59,5,29,57,22,139,80,65,23,125,249,134,171,16,40,149,41,131,12,129,131,67,32,55,4,31,168,378,271,104,19,161,5,5,7,110,41,4,14,3,105,1,71,434,32,31,19,53,12,13,35,68,259,97,66,15,242,20,6,12,84,255,41,116,112,25,64,24,73,7,161,82,703,16,36,43,46,20,47,8,24,279,34,2,210,42,51,23,89,20,4,139,167,265,393,44,297,9,4,45,158,66,9,17,4,3,4,101,19,4],"type":"bar"},{"x":["correlation","formulations","gen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4525,), (4525, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>study</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>affecting</span> <span style=''>visual</span> <span style=''>saliency</span> <span style='background-color:rgba(0, 255, 0, 0.5466666666666666);'>assessment</span> <br/><br/><span style=''>Since</span> <span style=''>the</span> <span style=''>early</span> <span style=''>2000s</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>visual</span> <span style=''>saliency</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>very</span> <span style=''>active</span> <span style=''>research</span> <span style=''>area</span> <span style=''>Each</span> <span style=''>year</span> <span style=''>more</span> <span style=''>and</span> <span style=''>more</span> <span style=''>new</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>published</span> <span style=''>in</span> <span style=''>the</span> <span style=''>main</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conferences</span> <span style=''>Nowadays</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>big</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenges</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>way</span> <span style=''>to</span> <span style=''>fairly</span> <span style=''>evaluate</span> <span style=''>all</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>assess</span> <span style=''>models</span> <span style=''>of</span> <span style=''>visual</span> <span style=''>saliency</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.40659340659340654);'>evaluation</span> <span style=''>is</span> <span style=''>divided</span> <span style=''>into</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>proposition</span> <span style=''>of</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.40659340659340654);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>Each</span> <span style='background-color:rgba(0, 255, 0, 0.3663366336633663);'>experiment</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>basic</span> <span style=''>question</span> <span style=''>1)</span> <span style=''>there</span> <span style=''>are</span> <span style=''>two</span> <span style=''>ground</span> <span style=''>truths</span> <span style=''>for</span> <span style=''>saliency</span> <span style='background-color:rgba(0, 255, 0, 0.40659340659340654);'>evaluation</span> <span style=''>what</span> <span style=''>are</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>between</span> <span style=''>eye</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>fixations</span> <span style=''>and</span> <span style=''>manually</span> <span style='background-color:rgba(0, 255, 0, 0.9166666666666667);'>segmented</span> <span style=''>salient</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Polynomial</span> <span style=''>Networks</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Machines</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>machines</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>models</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>We</span> <span style=''>extend</span> <span style=''>these</span> <span style=''>models</span> <span style=''>to</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>output</span> <span style=''>setting</span> <span style=''>ie</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>vector</span> <span style=''>valued</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>to</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>or</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>cast</span> <span style=''>this</span> <span style=''>as</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>3</span> <span style=''>way</span> <span style=''>tensor</span> <span style=''>whose</span> <span style=''>slices</span> <span style=''>share</span> <span style=''>a</span> <span style=''>common</span> <span style=''>basis</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>that</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>then</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>its</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>despite</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>it</span> <span style=''>involves</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>step</span> <span style=''>On</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excellent</span> <span style=''>accuracy</span> <span style=''>with</span> <span style=''>much</span> <span style=''>sparser</span> <span style=''>models</span> <span style=''>than</span> <span style=''>existi ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>from</span> <span style=''>Pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3431372549019607);'>Similarity</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unlabeled</span> <span style=''>Data</span> <br/><br/><span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>biggest</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454545);'>bottlenecks</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>its</span> <span style=''>high</span> <span style=''>labeling</span> <span style=''>cost</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>weakly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>called</span> <span style=''>SU</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>where</span> <span style=''>only</span> <span style=''>similar</span> <span style=''>(S)</span> <span style=''>data</span> <span style=''>pairs</span> <span style=''>(two</span> <span style=''>examples</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>class)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unlabeled</span> <span style=''>(U)</span> <span style=''>data</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>an</span> <span style=''>unbiased</span> <span style='background-color:rgba(255, 0, 0, 0.6094674556213017);'>estimator</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>risk</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>only</span> <span style=''>from</span> <span style=''>SU</span> <span style=''>data</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.8);'>minimizer</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.43243243243243246);'>parametric</span> <span style='background-color:rgba(255, 0, 0, 0.32758620689655166);'>convergence</span> <span style=''>rate</span> <span style=''>Finally</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Rare</span> <span style=''>Disease</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Physician</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Targeting</span> <span style=''>A</span> <span style=''>Factor</span> <span style=''>Graph</span> <span style=''>Approach</span> <br/><br/><span style=''>In</span> <span style=''>rare</span> <span style=''>disease</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physician</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>targeting</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>is</span> <span style=''>how</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physicians</span> <span style=''>who</span> <span style=''>are</span> <span style=''>treating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnosed</span> <span style=''>or</span> <span style=''>underdiagnosed</span> <span style=''>rare</span> <span style=''>diseases</span> <span style=''>patients</span> <span style=''>Rare</span> <span style=''>diseases</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incidence</span> <span style=''>rate</span> <span style=''>For</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>rare</span> <span style=''>disease</span> <span style=''>only</span> <span style=''>a</span> <span style=''>small</span> <span style=''>number</span> <span style=''>of</span> <span style=''>patients</span> <span style=''>are</span> <span style=''>affected</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fractional</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physicians</span> <span style=''>are</span> <span style=''>involved</span> <span style=''>The</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>targeting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodologies</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>profiling</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>under</span> <span style=''>mass</span> <span style=''>market</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>They</span> <span style=''>are</span> <span style=''>not</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>rare</span> <span style=''>disease</span> <span style=''>market</span> <span style=''>where</span> <span style=''>the</span> <span style=''>target</span> <span style=''>classes</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>The</span> <span style=''>authors</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>targets</span> <span style=''>by</span> <span style=''>jointly</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>physician</span> <span style=''>and</span> <span style=''>patient</span> <span style=''>features</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>data</span> <span style=''>spaces</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09405940594059406)
# 	architecture (0.08521923620933522)
# 	experimental (0.13366336633663367)
# 	different (0.2485855728429986)
# 	knowledge (0.134016973125884)
# 	information (0.24823196605374823)
# 	segmentation (0.08026874115983026)
# 	detection (0.12128712871287128)
# 	convolutional (0.13154172560113153)
# 	recognition (0.13932107496463933)
#
# Some Statistics words are:
# 	theoretical (0.15060851926977686)
# 	variables (0.14300202839756593)
# 	statistical (0.15212981744421908)
# 	stochastic (0.13539553752535496)
# 	estimation (0.1744421906693712)
# 	algorithm (0.38995943204868155)
# 	distribution (0.18255578093306288)
# 	inference (0.19421906693711968)
# 	dimensional (0.19929006085192696)
# 	regression (0.17849898580121704)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="28ae5204-164b-408d-8638-b030bb7174b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28ae5204-164b-408d-8638-b030bb7174b2")) {                    Plotly.newPlot(                        "28ae5204-164b-408d-8638-b030bb7174b2",                        [{"x":["correlation","formulations","generalized","dependency","estimation","structure","conditional","introduce","covariance","regression","framework","performance","structured","interactions","variables","perspective","formulation","reference","demonstrate","differently","simulation","naturally","disagreements","experiments","knowledge","effectiveness","partially","completing","alignment","individual","effective","nomination","applicability","extremely","adjacency","approximate","algorithm","algebraic","development","constraint","encapsulate","restricts","visualizing","arbitrary","parameters","polynomial","exploiting","consistent","differentiated","derivatives","solutions","expansions","ambiguity","connections","information","increases","performances","backpropagation","convergence","architectures","considers","generalizations","benchmark","outperformed","classification","operation","convolutional","sparseness","frequency","recognition","collection","additionally","handcrafting","representation","representations","application","extension","competitive","concurrently","susceptibility","analogous","exploration","multidimensional","automatic","decreases","systematic","combinations","distributed","experiment","quantization","sufficient","quantized","characterized","iteration","coordinate","conditions","assumption","precision","randomized","practical","complexity","literature","theoretical","deviation","denoising","efficiency","population","computation","justified","independent","additional","filtering","intensity","observation","injection","treatment","traditional","experimental","technique","reduction","restoration","statistical","neighbourhood","ultrasound","lipschitz","especially","exponential","logarithm","concurrent","randomised","continuous","parallelisation","numerical","approaches","expectation","maximizing","discrimination","potentially","discriminant","decomposed","comparisons","likelihood","significantly","alternative","simulated","dedicated","outperforms","integrates","heterogeneity","homogeneous","particularly","including","functional","approximation","performed","maximization","explicitly","presenting","observations","hyperparameter","probabilistic","predictions","different","hyperparameters","specified","integrating","dependencies","explanations","integration","submodular","phenomenon","computational","recommendation","advertisements","properties","increased","combinatorial","straightforward","computationally","intractable","encounters","challenge","objective","particular","efficient","formulate","optimization","recommend","terminate","formulated","specifically","assumptions","adversary","arbitrarily","delivered","resorting","celebrated","adversarial","distributional","encompasses","logarithmic","generalizes","constraints","generation","maintaining","algorithms","processing","heuristic","adaptively","prediction","justification","applicable","constrained","resulting","character","degrading","implementation","following","definition","artificial","intelligence","discussion","attention","importance","questions","incorrect","improvements","characterization","highlights","influence","techniques","integrate","precisely","classical","evaluated","classifiers","unlabeled","informativeness","potential","classifier","instances","perturbations","evaluating","virtually","criterion","representative","retraining","maintains","informative","respectively","combination","usefulnes ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nomination
# 	therapeutic
# 	davenport
# 	unmeasured
# 	majorization
# 	beautiful
# 	disaggregate
# 	aesthetic
# 	departure
# 	exogenous
# 	economists
# 	logitboost
# 	decomposability
# 	diarization
# 	collapsed
# 	uncollapsed
# 	inferential
# 	publishing
# 	supersparse
# 	smoothers
# Some words which never appear in Statistics papers:
# 	encapsulate
# 	differentiated
# 	handcrafting
# 	susceptibility
# 	ultrasound
# 	connectionist
# 	grounding
# 	sensorimotor
# 	occlusions
# 	reorganization
# 	quadrangle
# 	incidental
# 	quadrilateral
# 	monocular
# 	syntactic
# 	reflections
# 	morphology
# 	ambiguously
# 	quantifiers
# 	interdisciplinary

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0483158055174518e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7516666666666667
